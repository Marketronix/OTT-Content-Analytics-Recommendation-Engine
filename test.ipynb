# %%
import pandas as pd

# %%
df = pd.read_csv('./imdb_data/title.basics.tsv', sep='\t', low_memory=False)

# %%
df.isnull().sum()
# Out:
# tconst              0
# titleType           0
# primaryTitle       20
# originalTitle      20
# isAdult             0
# startYear           0
# endYear             0
# runtimeMinutes      0
# genres            666
# dtype: int64

# %%
# Make sure all rows are displayed
pd.set_option('display.max_rows', None)

# Show full value counts
print(df['genres'].value_counts())
# Out:
# genres
# Drama                               1315661
# Comedy                               761958
# Talk-Show                            739225
# News                                 609998
# Documentary                          564353
# Drama,Romance                        528872
# \N                                   519645
# Reality-TV                           373181
# Adult                                324993
# News,Talk-Show                       264599
# Short                                228235
# Drama,Short                          219979
# Family                               206287
# Game-Show                            192088
# Comedy,Short                         164786
# Documentary,Short                    162511
# Sport                                150346
# Music                                121562
# Romance                              117558
# Comedy,Talk-Show                     117300
# Comedy,Drama,Romance                 103041
# ...

# %%
filtered_df = df[df['genres'] == 'Reality-TV']

# Print the filtered rows
print(filtered_df)
# Out:
#              tconst  titleType  \
# 68224     tt0069645   tvSeries
# 72495     tt0074044   tvSeries
# 80132     tt0081916   tvSeries
# 103718    tt0106111   tvSeries
# 109581    tt0112136   tvSeries
# ...             ...        ...
# 11701958  tt9916448  tvEpisode
# 11701961  tt9916454  tvEpisode
# 11701963  tt9916458  tvEpisode
# 11702019  tt9916576  tvEpisode
# 11702074  tt9916694  tvEpisode
#
#                                                primaryTitle  \
# 68224                                         Thrillseekers
# 72495                                                 Rebop
# 80132                                    The People's Court
# 103718                   Real Stories of the Highway Patrol
# 109581                             The Real World Stockholm
# ...                                                     ...
# 11701958    Tag 3: Carmen & Timo, Motto: Rot-Weiße-Hochzeit
# 11701961  Tag 4: Marina & Kevin, Motto: Prinzessinen-Hoc...
# ...

# %%
df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              5  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1                     Short
